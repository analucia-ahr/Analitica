# %% [markdown]
# 1. Carga los datos usando tu lector de csv o con pandas. Es recomendable hacerlo con pandas.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("covid19_tweets.csv")
data.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %% [markdown]
# 2. Verifica la cantidad de datos que tienes, las variables que contiene cada vector de datos e identifica el tipo de variables.

# %%
data.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    7.443600e+04   74436.000000     7.443600e+04
# mean     1.059513e+05    2154.721170     1.529747e+04
# std      8.222900e+05    9365.587474     4.668971e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.660000e+02     153.000000     2.200000e+02
# 50%      9.600000e+02     552.000000     1.927000e+03
# 75%      5.148000e+03    1780.250000     1.014800e+04
# max      1.389284e+07  497363.000000     2.047197e+06

# %%
data.count()
# Out:
# user_name           74436
# user_location       59218
# user_description    70079
# user_created        74436
# user_followers      74436
# user_friends        74436
# user_favourites     74436
# user_verified       74436
# date                74436
# text                74436
# hashtags            53002
# source              74424
# is_retweet          74436
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74436 entries, 0 to 74435
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_name         74436 non-null  object
#  1   user_location     59218 non-null  object
#  2   user_description  70079 non-null  object
#  3   user_created      74436 non-null  object
#  4   user_followers    74436 non-null  int64
#  5   user_friends      74436 non-null  int64
#  6   user_favourites   74436 non-null  int64
#  7   user_verified     74436 non-null  bool
#  8   date              74436 non-null  object
#  9   text              74436 non-null  object
#  10  hashtags          53002 non-null  object
#  11  source            74424 non-null  object
#  12  is_retweet        74436 non-null  bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 6.4+ MB

# %% [markdown]
# 3. Analiza las variables para saber qué representa cada una y en qué rangos se encuentran. Si la descripción del problema no te lo indica, utiliza el máximo y el mínimo para encontrarlo.

# %%
data.sort_values(['user_followers'], ascending = False).head(10)
# Out:
#       user_name   user_location  \
# 6959       CGTN  Beijing, China
# 13450      CGTN  Beijing, China
# 16194      CGTN  Beijing, China
# 235        CGTN  Beijing, China
# 2837       CGTN  Beijing, China
# 5344       CGTN  Beijing, China
# 20483      CGTN  Beijing, China
# 20378      CGTN  Beijing, China
# 24243      CGTN  Beijing, China
# 23721      CGTN  Beijing, China
#
#                                         user_description         user_created  \
# 6959   #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 13450  #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 16194  #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 235    #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 2837   #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 5344   #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# ...

# %%
data.sort_values(['user_location'], ascending = False).head(2000)
# Out:
#                             user_name user_location  \
# 2572                   ✊Franc-Tireur🗽             🪐
# 11869                      🐝BeeHappy🐝             🪐
# 11692                      🐝BeeHappy🐝             🪐
# 11618                      🐝BeeHappy🐝             🪐
# 27153  🏳️‍🌈ÐΛⱤƬⱧ §ⱠӨ₮Я🇪🇸🇮🇪🏴󠁧󠁢󠁳󠁣󠁴󠁿🇬🇧🇺🇸   🦄🌈❤️🧡💛💚💙💜🌈🦄
# ...                               ...           ...
# 64295                               6   everywhere
# 25594                       Milogamez    everywhere
# 71315                   Chap PlayBook    everywhere
# 20316                   tony_revsoc99        europe
# 36640                   magudeshwaran         erode
#
#                                         user_description         user_created  \
# 2572   Committed to getting into #GoodTrouble #ICantB...  2014-10-28 15:00:14
# 11869                                                🏝🏖🏔  2020-01-24 19:49:32
# 11692                                                🏝🏖🏔  2020-01-24 19:49:32
# ...

# %%
data.sort_values(['user_verified'], ascending = False).head(10)
# Out:
#                                                user_name  \
# 37218                                              NEWS9
# 47831                                     Philip N Cohen
# 11995                              German Embassy Kigali
# 47810                                  Belfast Telegraph
# 12002                                            NBC DFW
# 64083                                       BHU Official
# 12008                                        tv9gujarati
# 30826                                           SpotboyE
# 47824  Jackson-Madison County Regional Health Department
# 12019                                        News-Leader
#
#                    user_location  \
# 37218                  BENGALURU
# 47831                        NaN
# 11995                     Rwanda
# 47810  Belfast, Northern Ireland
# 12002                        NaN
# 64083            Varanasi, India
# 12008             Gujarat, India
# 30826                     Mumbai
# ...

# %%
data.sort_values(['is_retweet'], ascending = False).head(10)
# Out:
#                   user_name               user_location  \
# 0                    ᏉᎥ☻լꂅϮ                  astroworld
# 49648          Hotpage News               United States
# 49628           Bethanie Le           Orange County, CA
# 49627      PRMAC_Consulting  Victoria, British Columbia
# 49626     ~ Beata ~ #MaskUp  In America, right matters.
# 49625      swearing account                          UK
# 49624        ciaolimoncello                         NaN
# 49623  Caroline Dwyer, AICP                  Durham, NC
# 49622              XRP_THOR                         NaN
# 49621        NC Health News              North Carolina
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 49648  Top 50 Headlines of the Day #COVID19 #Coronavirus  2009-03-12 14:16:30
# 49628  Public Relations @ChapmanU | @ucriverside Grad...  2015-07-01 16:40:31
# ...

# %%
data.sort_values(['user_friends'], ascending = False).head(10)
# Out:
#                user_name       user_location  \
# 12021        Tim Fargo 😷  2x Inc. 500 winner
# 22924        Tim Fargo 😷  2x Inc. 500 winner
# 20391        Tim Fargo 😷  2x Inc. 500 winner
# 29229        Tim Fargo 😷  2x Inc. 500 winner
# 37508        Tim Fargo 😷  2x Inc. 500 winner
# 59568        Tim Fargo 😷  2x Inc. 500 winner
# 14520  #ismyhairmessedup       Long Beach CA
# 45590  #ismyhairmessedup       Long Beach CA
# 50218  #ismyhairmessedup       Long Beach CA
# 62866      Anthony Casas       United States
#
#                                         user_description         user_created  \
# 12021  CEO of Social Jukebox #digitalnomad #socialtoo...  2010-10-09 17:40:24
# 22924  CEO of Social Jukebox #digitalnomad #socialtoo...  2010-10-09 17:40:24
# 20391  CEO of Social Jukebox #digitalnomad #socialtoo...  2010-10-09 17:40:24
# 29229  CEO of Social Jukebox #digitalnomad #socialtoo...  2010-10-09 17:40:24
# ...

# %%
data.sort_values(['user_favourites'], ascending = False).head(10)
# Out:
#                   user_name      user_location  \
# 14504   Chelsea Anderson.♥️  South Dakota, USA
# 71764  paolo ignazio marong                NaN
# 69943  paolo ignazio marong                NaN
# 70610  paolo ignazio marong                NaN
# 62200  paolo ignazio marong                NaN
# 62446  paolo ignazio marong                NaN
# 62126  paolo ignazio marong                NaN
# 53316  paolo ignazio marong                NaN
# 53438  paolo ignazio marong                NaN
# 44330  paolo ignazio marong                NaN
#
#                                         user_description         user_created  \
# 14504  Activist, photography, reading, drawing, and s...  2013-03-06 04:11:45
# 71764  libero professionista, analista sereno navigat...  2013-04-10 09:29:25
# 69943  libero professionista, analista sereno navigat...  2013-04-10 09:29:25
# 70610  libero professionista, analista sereno navigat...  2013-04-10 09:29:25
# ...

# %% [markdown]
# 4. Basándose en la media, mediana y desviación estándar de cada variable, ¿Qué conclusiones puedes entregar de los datos?
#     - Primero que nada, desde mi interpretación de los datos, pude notar que no por el hecho de tener una cuenta verificada, esto implica que toda la información, o en este caso, los tweets, que compartas sean verídicos. Ya que el tener una "palomita azul" solo implica que tu cuenta es activa, notoria y auténtica.
#         - Al momento de utilizar *data.sort_values(['user_followers'], ascending = False).head(100)* se puede notar que el punto previamente descrito es cierto, ya que las cuentas con más seguidores, y por lo tanto, con más actividad, son aquellas que están verificadas.
#     - En el caso de la ubicación que proporcionan los usuarios, esta no es siempre certera. Te puedes encontrar desde un emoji como ubicación hasta un "Uranus" o un "everywhere". Sin embargo, algunos consumidores de la plataforma si indican su locación, aunque sea de manera más ambigua (como ejemplo tenemos "Europe").
#         - Los ususarios pueden tener esta iniciativa de no indicar su ubicación ya sea tanto por razones de seguridad, como solo por gusto y "adornar" su perfl, como lo es en el caso de los emoticones.
#         - Por otro lado, aquellos usuarios que proporcionan de manera correcta su locación ayudan a que la plataforma relacione el contenido que esta brinda con otros usuarios que interactuan en la misma región y consumen el mismo contenido.
#     - Los # utilizados por los internautas alrededor del mundo son sumamente similares ya que el mismo tema ha sido "trending topic" durante mucho tiempo: Covid-19. Siendos los hashtags: #Coronavirus y #Covid19 los mas recurrentes entre los clientes de la plataforma. En adición a estos hashtags, se les agrega su respectivo país para generar más impacto en el mismo.

# %% [markdown]
# Bibliografía:
# - Requisitos de verificación de Twitter: Cómo obtener la insignia de verificación azul. (2022, January 21). Retrieved May 12, 2022, from Twitter.com website: https://help.twitter.com/es/managing-your-account/about-twitter-verified-accounts#:~:text=La%20insignia%20azul%20de%20verificaci%C3%B3n,aut%C3%A9nticay%20notoria%20y%20estar%20activa.
